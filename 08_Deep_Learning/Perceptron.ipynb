# %%
from sklearn.linear_model import Perceptron
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

X, y = make_classification(n_samples=1000, n_features=10, n_classes=2, random_state=42)

X_train, X_test, Y_train, Y_test = train_test_split(X, y , random_state=42)
clf = Perceptron(
    max_iter=1000,
    eta0=0.1,
    random_state=42,
    tol=1e-3,
    shuffle=True
)


clf.fit(X_train, Y_train)
accuracy = clf.score(X_test, Y_test)

# %%
print(accuracy)
# Out:
# 0.852

# %%
# !pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (2.21.0)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=25.9.23 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (26.1)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (7.35.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (83.0.0)
# Requirement already satisfied: six>=1.12.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (1.83.0)
# Requirement already satisfied: keras>=3.12.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (2.5.1)
# Requirement already satisfied: h5py<3.15.0,>=3.11.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow) (2026.7.22)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (15.0.0)
# Requirement already satisfied: namex in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow) (0.19.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/envs/tf/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow) (0.1.2)

# %%
import tensorflow as tf

# %%
tf
# Out:
# <module 'tensorflow' from '/opt/anaconda3/envs/tf/lib/python3.12/site-packages/tensorflow/__init__.py'>
