# %%
import pandas as pd

# %%
# Series is like a list with a label
# 1 dimesional arrays
s1=pd.Series([1,4,5,33,66,88])

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
print(s1)
# Out:
# 0     1
# 1     4
# 2     5
# 3    33
# 4    66
# 5    88
# dtype: int64

# %%
s1=pd.Series([1,4,5,33,66,88], index=["harry", "rudr", "daksh","vanshul","krishna","satwik"])

# %%
s1
# Out:
# harry       1
# rudr        4
# daksh       5
# vanshul    33
# krishna    66
# satwik     88
# dtype: int64

# %%
# DataFrame= 2 Dimensional table with rows and columns
ata={
    "Name":["Alice","Bob","John"],
    "Age":[20,30,33],
    "City":["Delhi","Chandigarh","Bombay"]
}

# %%
df=pd.DataFrame(data)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')
