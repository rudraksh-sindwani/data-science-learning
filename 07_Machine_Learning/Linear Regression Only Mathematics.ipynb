# %%
import pandas as pd 
import matplotlib.pyplot as plt

data = pd.read_csv("studytime_scores.csv")
plt.scatter(data.studytime, data.scores)
plt.show()

def loss_function(m,b,points):
    total_error= 0
    for i in range(len(points)):
        x = points.iloc[i].studytime
        y = points.ilco[i].scores
        total_error += ( y - (m*x+b))** 2
    total_error/float(len(points))

def gradient_descent(m_now, b_now , points, L):
    m_gradient = 0
    b_gradient = 0

    n= len(points)

    for i in range(n):
        x = points.iloc[i].studytime
        y = points.iloc[i].scores

        m_gradient += -(2/n) * x * (y-(m_now*x+b_now))
        b_gradient += -(2/n) *  (y-(m_now*x+b_now))

    m = m_now-m_gradient *L
    b = b_now-b_gradient*L
    return m ,b

m=0
b=0
L=0.01
epochs = 3000

for i in range(epochs):
    if i % 50 == 0 :
        print(f"Epochs is {i}")
    
    m , b = gradient_descent(m,b,data,L)

print(m,b)
plt.scatter(data.studytime,data.scores,color = "black")
plt.plot(list(range(0,11)), [m*x+b for x in range(0,11)],color = "red")
plt.show()
# Out:
# Epochs is 0
# Epochs is 50
# Epochs is 100
# Epochs is 150
# Epochs is 200
# Epochs is 250
# Epochs is 300
# Epochs is 350
# Epochs is 400
# Epochs is 450
# Epochs is 500
# Epochs is 550
# Epochs is 600
# Epochs is 650
# Epochs is 700
# Epochs is 750
# Epochs is 800
# Epochs is 850
# Epochs is 900
# Epochs is 950
# Epochs is 1000
# Epochs is 1050
# Epochs is 1100
# Epochs is 1150
# Epochs is 1200
# Epochs is 1250
# Epochs is 1300
# Epochs is 1350
# Epochs is 1400
# Epochs is 1450
# Epochs is 1500
# Epochs is 1550
# Epochs is 1600
# Epochs is 1650
# Epochs is 1700
# Epochs is 1750
# Epochs is 1800
# Epochs is 1850
# Epochs is 1900
# Epochs is 1950
# Epochs is 2000
# Epochs is 2050
# Epochs is 2100
# Epochs is 2150
# Epochs is 2200
# Epochs is 2250
# Epochs is 2300
# Epochs is 2350
# Epochs is 2400
# Epochs is 2450
# Epochs is 2500
# Epochs is 2550
# Epochs is 2600
# Epochs is 2650
# Epochs is 2700
# Epochs is 2750
# Epochs is 2800
# Epochs is 2850
# Epochs is 2900
# Epochs is 2950
# 5.197078550464595 44.96936296408606
