# %%
import numpy as np

# %%
array=np.array([1,33,5,46,4,4])

# %%
print(np.mean(array))
# Out:
# 17.8

# %%
print(np.max(array))
# Out:
# 46

# %%
print(np.min(array))
# Out:
# 1

# %%
print(np.std(array))
# Out:
# 18.23622768008779

# %%
print(np.var(array))
# Out:
# 332.56000000000006

# %%
print(np.sum(array))
# Out:
# 89

# %%
print(np.prod(array))
# Out:
# 30360

# %%
print(np.median(array))
# Out:
# 5.0

# %%
print(np.percentile(array,50))
# Out:
# 5.0

# %%
print(np.argmin(array))
# Out:
# 0

# %%
print(np.argmax(array))
# Out:
# 3

# %%
print(np.unique(array))
# Out:
# [ 1  4  5 33 46]

# %%
print(np.diff(array))
# Out:
# [ 32 -28  41 -42   0]

# %%
print(np.cumsum(array))
# Out:
# [ 1 34 39 85 89 93]
