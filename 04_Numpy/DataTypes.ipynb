# %%
import numpy as np

# %%
array=np.array([1,44,2,3,22])

# %%
array.dtype
# Out:
# dtype('int64')

# %%
array.astype("float64")
# Out:
# array([ 1., 44.,  2.,  3., 22.])

# %%
array.nbytes
# Out:
# 40

# %%
array2=np.array([1+2j,2+3j,6+2j])
print(array2)
# Out:
# [1.+2.j 2.+3.j 6.+2.j]
