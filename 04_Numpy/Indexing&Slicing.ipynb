# %%
import numpy as np
arr = np.array([[1,2,3],[4,5,6],[6,7,8],[11,12,13]])

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [11, 12, 13]])

# %%
flat = arr.flatten()

# %%
flat
# Out:
# array([ 1,  2,  3,  4,  5,  6,  6,  7,  8, 11, 12, 13])

# %%
print(flat[0])
# Out:
# 1

# %%
flat[3:6]
# Out:
# array([4, 5, 6])

# %%
flat[0:]
# Out:
# array([ 1,  2,  3,  4,  5,  6,  6,  7,  8, 11, 12, 13])

# %%
flat[:5]
# Out:
# array([1, 2, 3, 4, 5])

# %%
flat[3:]
# Out:
# array([ 4,  5,  6,  6,  7,  8, 11, 12, 13])

# %%
flat[3:13]
# Out:
# array([ 4,  5,  6,  6,  7,  8, 11, 12, 13])

# %%
print(flat[::2])
# Out:
# [ 1  3  5  6  8 12]

# %%
b=flat[4:7]

# %%
b
# Out:
# array([5, 6, 6])

# %%
b[0]=4444

# %%
b
# Out:
# array([4444,    6,    6])

# %%
flat
# Out:
# array([   1,    2,    3,    4, 4444,    6,    6,    7,    8,   11,   12,
#          13])

# %%
arr
# Out:
# array([[ 1,  2,  3],
#        [ 4,  5,  6],
#        [ 6,  7,  8],
#        [11, 12, 13]])

# %%
array1=np.array([1,2,3,4,5,6,6,733,22,55])
index=[1,5,7]
print(array1[index])
# Out:
# [  2   6 733]

# %%
array2=np.array([1,2,3,4,5,6,6,733,22,55])
mask=array2>25
print(array2[mask])
# Out:
# [733  55]

# %%
array3=np.array([1, 2, 3, 4, 5, 6])
index=[1,3,5]
print(array3[index])
# Out:
# [2 4 6]
