# %%
l=[3,5,6,67]

# %%
for item in l:
    print(item)
# Out:
# 3
# 5
# 6
# 67

# %%
for i in range(7,10):
    print(i)
# Out:
# 7
# 8
# 9

# %%
i=0
while i < 1:
    print(i)
    i=i+1
# Out:
# 0

# %%
for item in l:
    pass
print("hello")
# Out:
# hello

# %%
l=["apple", "banana", "grapes"]
for item in l:
    if (item=="banana"):
        break
    print(item)
# Out:
# apple

# %%
l=["apple", "banana", "grapes"]
for item in l:
    if (item=="banana"):
        continue
    print(item)
# Out:
# apple
# grapes
