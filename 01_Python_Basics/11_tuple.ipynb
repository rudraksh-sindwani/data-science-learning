# %%
t=(1,23,2,3)

# %%
t
# Out:
# (1, 23, 2, 3)

# %%
len(t)
# Out:
# 4

# %%
t[2]
# Out:
# 2

# %%
person=("alice",25,"engineer")
name,age,profession=person

# %%
profession
# Out:
# 'engineer'

# %%
name
# Out:
# 'alice'

# %%
t.count(1)
# Out:
# 1
