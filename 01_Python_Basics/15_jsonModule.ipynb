# %%
import json

# %%
obj={"name":"rudr","age":20,"company":"IBM","Salary":45000}
s=json.dumps(obj)
type(s)
print(s)
# Out:
# {"name": "rudr", "age": 20, "company": "IBM", "Salary": 45000}

# %%
d=json.loads('{"name": "rudr", "age": 20, "company": "IBM", "Salary": 45000}')

# %%
type(d)
# Out:
# dict

# %%
file=open("data.json","w")

# %%
json.dump(obj,file)

# %%
file.close()
