# %%
a=11
b=5

# %%
a+b
# Out:
# 16

# %%
a*b
# Out:
# 55

# %%
a/b
# Out:
# 2.2

# %%
a//b
# Out:
# 2

# %%
a%b
# Out:
# 1

# %%
2**6
# Out:
# 64

# %%
a**b
# Out:
# 161051

# %%
a>=b
# Out:
# True

# %%
b1= True
b2= False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
b1 and b2
# Out:
# False

# %%
b1 or b2
# Out:
# True

# %%
a=40
a+=4

# %%
a
# Out:
# 44

# %%
11//2
# Out:
# 5

# %%
a = 11

# %%
a //= 2

# %%
a
# Out:
# 5
