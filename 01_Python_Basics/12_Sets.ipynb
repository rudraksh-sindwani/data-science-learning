# %%
a= set()

# %%
type(a)
# Out:
# set

# %%
s={1,2,3,55,66,6,3}

# %%
s
# Out:
# {1, 2, 3, 6, 55, 66}

# %%
type(s)
# Out:
# set

# %%
u=set([1,2,2,3,4,5,3,7])
print(u)
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
u.add(34)

# %%
u
# Out:
# {1, 2, 3, 4, 5, 7, 34}

# %%
u.update([55,44,33])

# %%
u
# Out:
# {1, 2, 3, 4, 5, 7, 33, 34, 44, 55}

# %%
u.remove(33)

# %%
u
# Out:
# {1, 2, 3, 4, 5, 7, 34, 44, 55}

# %%
u.discard(23)

# %%
u
# Out:
# {2, 3, 4, 5, 7, 34, 44, 55}

# %%
u
# Out:
# {2, 3, 4, 5, 7, 34, 44, 55}

# %%
set1={1,3,4,2}
set2={5,7,8,3}

# %%
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 7, 8}

# %%
set1.intersection(set2)
# Out:
# {3}

# %%
sub={1,3}

# %%
sub.issubset(set1)
# Out:
# True

# %%
set1.issuperset(sub)
# Out:
# True

# %%
d={1,2,3,5}

# %%
type(d)
# Out:
# set
