# %%
a= input("enter the value of a") #by default it takes string
# Out:
# enter the value of a 45

# %%
a
# Out:
# '45'

# %%
b= input("enter the value of b")
# Out:
# enter the value of b 30

# %%
b
# Out:
# '30'

# %%
a+b
# Out:
# '4530'

# %%
int(a)+int(b)
# Out:
# 75
