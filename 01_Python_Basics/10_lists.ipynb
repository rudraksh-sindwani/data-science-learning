# %%
l=[1,2,4,56]

# %%
l
# Out:
# [1, 2, 4, 56]

# %%
l[1]=5

# %%
l
# Out:
# [1, 5, 4, 56]

# %%
l.append(9)

# %%
l
# Out:
# [1, 5, 4, 56, 9]

# %%
l2=[5,7]

# %%
l.extend(l2)

# %%
l
# Out:
# [1, 5, 4, 56, 9, 5, 7]

# %%
l.insert(1,30)

# %%
l
# Out:
# [1, 30, 5, 4, 56, 9, 5, 7]

# %%
number=l.pop(4)

# %%
number
# Out:
# 56

# %%
l
# Out:
# [1, 30, 5, 4, 9, 5, 7]

# %%
l.index(1)
# Out:
# 0

# %%
l.index(9)
# Out:
# 4

# %%
l.count(4)
# Out:
# 1

# %%
l.sort()

# %%
l
# Out:
# [1, 4, 5, 5, 7, 9, 30]

# %%
n=[1,3,2,6,4,7,2]

# %%
sorted(n)
# Out:
# [1, 2, 2, 3, 4, 6, 7]

# %%
y=[1,2,True,False,[4,7]]

# %%
y
# Out:
# [1, 2, True, False, [4, 7]]

# %%
y[4]
# Out:
# [4, 7]

# %%
y[4][1]
# Out:
# 7

# %%
s="rudr-daksh-vanshul-krishna-anuj"

# %%
s.split("-")
# Out:
# ['rudr', 'daksh', 'vanshul', 'krishna', 'anuj']
