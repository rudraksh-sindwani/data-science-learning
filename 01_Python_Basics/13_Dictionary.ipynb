# %%
d={}

# %%
type(d)
# Out:
# dict

# %%
student={
    "name": "Rudr",
    "age":20,
    "grade":"A"
}

# %%
student["name"]
# Out:
# 'Rudr'

# %%
student.get("name4")

# %%
student = {"name": "Alice", "age": 25, "grade": "A"}

# %%
student["age"]=67

# %%
student
# Out:
# {'name': 'Alice', 'age': 67, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['Alice', 67, 'A'])

# %%
student.update({"name":"harry"})

# %%
student
# Out:
# {'name': 'harry', 'age': 67, 'grade': 'A'}

# %%
student.update({"name":"ruchika","language":"english"})

# %%
student
# Out:
# {'name': 'ruchika', 'age': 67, 'grade': 'A', 'language': 'english'}

# %%
student.popitem()
# Out:
# ('language', 'english')

# %%
student
# Out:
# {'name': 'ruchika', 'age': 67, 'grade': 'A'}
