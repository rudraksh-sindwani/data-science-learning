# %%
cube=lambda x:x*x*x

# %%
cube(3)
# Out:
# 27

# %%
s=(lambda x:x*x)

# %%
s(4)
# Out:
# 16

# %%
from functools import reduce
numbers = [1, 2, 3, 4]
product = reduce(lambda x, y: x * y, numbers)
print(product) # Output: 24
# Out:
# 24
