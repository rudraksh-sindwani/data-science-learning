# %%
name="harry"

# %%
name
# Out:
# 'harry'

# %%
name.upper()
# Out:
# 'HARRY'

# %%
name.endswith("ry")
# Out:
# True

# %%
name.endswith("kl")
# Out:
# False

# %%
name.lower()
# Out:
# 'harry'

# %%
name.count("A")
# Out:
# 0

# %%
name.count("r")
# Out:
# 2

# %%
s = "RudrakshSidnwani"
print(len(s))
# Out:
# 16

# %%
s[0:5]
# Out:
# 'Rudra'

# %%
s[1:-1]
# Out:
# 'udrakshSidnwan'

# %%
s[1:15]
# Out:
# 'udrakshSidnwan'

# %%
s[-15:-1]
# Out:
# 'udrakshSidnwan'

# %%
"python".find("th")
# Out:
# 2

# %%
"+".join(["2025", "04", "14"])
# Out:
# '2025+04+14'
