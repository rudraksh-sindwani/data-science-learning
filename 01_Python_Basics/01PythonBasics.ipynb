# %%
a=5

# %%
b=9

# %%
a+b
# Out:
# 14

# %%
name="harry"

# %%
# this is a comment

# %%
type(name)
# Out:
# str

# %%
a="677"
b="555"

# %%
print(a+b)
# Out:
# 677555

# %%
(int(a)+int(b))  #typecasting
# Out:
# 1232

# %%
name
# Out:
# 'harry'
