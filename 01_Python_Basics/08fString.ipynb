# %%
s="harry"

# %%
s
# Out:
# 'harry'

# %%
s.upper()
# Out:
# 'HARRY'

# %%
name="John"
age=55
print("my name is {} and i am {} years old.".format(name,age))
# Out:
# my name is John and i am 55 years old.

# %%
print(f"my name is {name} and I am {age} old.")
# Out:
# my name is John and I am 55 old.

# %%
print(f"{'python':>10}")
print(f"{'python':<10}")
print(f"{'python':^10}")
# Out:
#     python
# python
#   python
