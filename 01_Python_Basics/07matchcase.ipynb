# %%
code=2000

# %%
match code:
    case 200:
        print("response ok")
    case 400:
        print("bad")
    case 404:
        print("not found")
    case _:
        print("nothing")
print("end program")
# Out:
# nothing
# end program
